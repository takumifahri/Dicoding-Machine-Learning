# %% [markdown]
# # Kegunaan Spreadsheet
#
# Spreadsheet digunakan untuk mengelola, menganalisis, dan memvisualisasikan data secara efisien. Beberapa kegunaan utama spreadsheet antara lain:
#
# - Menyimpan informasi secara detail.
# - Membuat tabel data dengan lebih mudah.
# - Membantu dalam perhtiungan matematis dan statistik.
# - Membuat grafik dan diagram untuk visualisasi data.
# - Lengkap dengan rumus-rumus yang membantu dalam perhitungan data.

# %% [markdown]
# # Shortcut SpreadSheet
# | Tombol Keyboard              | Fungsi                                                                                                                                           |
# |------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------|
# | Tab                          | Mengakhiri masukan data pada sebuah sel dan bergeser ke sel selanjutnya secara horizontal (ke kanan).                                             |
# | Enter                        | Mengakhiri sebuah masukan data dan berpindah satu baris ke bawah.                                                                                |
# | Panah ke atas                | Berpindah satu sel ke atas.                                                                                                                      |
# | Panah ke bawah               | Berpindah satu sel ke bawah.                                                                                                                     |
# | Panah ke kanan               | Berpindah satu sel ke kanan.                                                                                                                     |
# | Panah ke kiri                | Berpindah satu sel ke kiri.                                                                                                                      |
# | Ctrl + arah panah            | Berpindah ke sel paling luar berdasarkan arah yang dimasukkan.                                                                                   |
# | Shift + arah panah           | Menyorot sel berdasarkan arah yang diberikan.                                                                                                    |
# | Ctrl + Shift + arah panah    | Menyorot seluruh sel yang berisi data sesuai arah yang diberikan.                                                                                |
# | Ctrl + C                     | Menduplikasi (copy) isi data dari suatu sel.                                                                                                     |
# | Ctrl + X                     | Memindahkan (cut) isi data dari suatu sel.                                                                                                       |
# | Ctrl + V                     | Menempelkan (paste) data hasil duplikasi atau pemindahan yang dilakukan sebelumnya.                                                              |
# | Ctrl + Z                     | Mengembalikan ke kondisi perubahan data terakhir (Undo).                                                                                         |
# | Ctrl + Y                     | Membatalkan perintah undo atau kembali ke kondisi sebelum perintah Undo (Redo).                                                                  |

# %% [markdown]
# # Menu Bar pada Google Sheets
#
# Menu bar berada tepat di bawah judul berkas. Menu yang disediakan oleh Google Sheets mulai dari **File** hingga **Help**.
#
# ---
#
# ## Menu File
#
# | Nama Menu              | Kegunaan                                                                                                                                                                                                                 |
# |------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Share                  | Membagikan berkas agar dapat dilihat, diubah, atau dikomentari oleh pengguna lain. Cocok untuk kolaborasi.                                                                                                               |
# | New                    | Membuat berkas spreadsheet baru atau dokumen lain seperti Google Docs, Google Slides, dll.                                                                                        |
# | Import                 | Memasukkan berkas lain ke spreadsheet. Mendukung format csv, txt, tsv, tab, htm, html, xls, xlsx, xlsm, xlt, xltm, xltx, ods.                                                     |
# | Make a copy            | Menduplikasi berkas yang sedang dikerjakan.                                                                                                                                                                              |
# | Download               | Mengunduh berkas ke komputer.                                                                                                                                                                                            |
# | Email as attachment    | Mengirimkan berkas sebagai lampiran email.                                                                                                                                                                               |
# | Make available offline | Mengaktifkan mode offline agar bisa mengedit tanpa koneksi internet. Sinkronisasi terjadi saat online.                                                                            |
# | Version history        | Melihat riwayat perubahan data.                                                                                                                                                                                          |
# | Rename                 | Mengubah nama berkas spreadsheet.                                                                                                                                                                                        |
# | Move                   | Memindahkan berkas ke direktori lain di Google Drive.                                                                                                                                                                   |
# | Move to trash          | Menghapus berkas, namun masih bisa dikembalikan dari trash.                                                                                                                                                             |
# | Publish to the web     | Membagikan berkas ke web dengan embed link.                                                                                                                                                                              |
# | Email collaborators    | Mengirim pesan ke kolaborator berkas.                                                                                                                                                                                    |
# | Document details       | Melihat detail berkas seperti lokasi penyimpanan, pemilik, tanggal dibuat, dan dimodifikasi.                                                                                                                            |
# | Settings               | Mengubah pengaturan seperti zona waktu, bahasa, dll.                                                                                                                                                                     |
# | Print                  | Mencetak berkas spreadsheet.                                                                                                                                                                                             |
#
# ---
#
# ## Menu Edit
#
# | Nama Menu         | Kegunaan                                                                                       |
# |-------------------|------------------------------------------------------------------------------------------------|
# | Undo              | Mengembalikan perubahan terakhir.                                                              |
# | Redo              | Membatalkan perintah undo.                                                                     |
# | Cut               | Memindahkan isi data dari suatu sel.                                                           |
# | Copy              | Menduplikasi isi data dari suatu sel.                                                          |
# | Paste             | Menempelkan data hasil cut/copy.                                                               |
# | Paste special     | Menempelkan data dengan pilihan khusus (misal hanya value, hanya format, dll).                 |
# | Find and replace  | Mencari data tertentu dan menggantinya dengan data baru.                                       |
# | Delete value      | Menghapus nilai dalam sel tanpa mengubah format.                                               |
# | Delete row        | Menghapus baris tertentu.                                                                      |
# | Delete column     | Menghapus kolom tertentu.                                                                      |
# | Delete cells and shift up   | Menghapus sel dan menggeser data di bawahnya ke atas.                                |
# | Delete cells and shift left | Menghapus sel dan menggeser data di kanannya ke kiri.                                |
# | Clear notes       | Menghapus catatan pada sel terpilih.                                                           |
# | Remove checkbox   | Menghapus checkbox pada sel.                                                                   |
#
# ---
#
# ## Menu View
#
# | Nama Menu         | Kegunaan                                                                                       |
# |-------------------|------------------------------------------------------------------------------------------------|
# | Freeze            | Membekukan baris/kolom agar tetap terlihat saat scroll.                                        |
# | Gridlines         | Menampilkan garis sel pada spreadsheet.                                                        |
# | Protected range   | Menampilkan sel yang terproteksi.                                                              |
# | Formula bar       | Menampilkan bar khusus untuk formula/rumus.                                                    |
# | Show formula      | Menampilkan formula pada sel.                                                                  |
# | Hidden sheets     | Menampilkan sheet yang disembunyikan.                                                          |
# | Zoom              | Memperbesar tampilan spreadsheet.                                                              |
# | Full screen       | Menampilkan spreadsheet dalam layar penuh.                                                     |

# %% [markdown]
# # Menu Insert, Format, Data, Tools, Add-ons, dan Help pada Google Sheets
#
# Menu bar pada Google Sheets menyediakan berbagai fitur penting untuk mengelola data. Berikut penjelasan menu-menu lanjutan:
#
# ---
#
# ## Menu Insert
#
# | Nama Menu            | Kegunaan                                                                                                   |
# |----------------------|------------------------------------------------------------------------------------------------------------|
# | Row above            | Memasukkan baris baru di atas sel yang sedang dipilih.                                                     |
# | Row below            | Memasukkan baris baru di bawah sel yang sedang dipilih.                                                    |
# | Column left          | Memasukkan kolom baru di samping kiri sel yang sedang dipilih.                                             |
# | Column right         | Memasukkan kolom baru di samping kanan sel yang sedang dipilih.                                            |
# | Cells and shift down | Menambahkan sel baru dengan menggeser ke bawah dari sel yang aktif saat itu.                               |
# | Cells and shift right| Menambahkan sel baru dengan menggeser ke kanan dari sel yang aktif saat itu.                               |
# | Chart                | Membuat grafik atau diagram berdasarkan data yang dibuat.                                                  |
# | Image                | Memasukkan gambar ke dalam sel yang aktif saat itu.                                                        |
# | Drawing              | Memasukkan objek sederhana seperti garis, bangun sederhana, dll.                                           |
# | Function             | Memasukkan rumus atau fungsi yang digunakan dalam spreadsheet.                                             |
# | Insert link          | Memasukkan tautan ke dalam sel.                                                                            |
# | Checkbox             | Membuat checkbox dalam sebuah sel.                                                                         |
# | Comment              | Memberi komentar pada sel yang dipilih.                                                                    |
# | Note                 | Membuat catatan pada sel tertentu. Notes bisa diakses oleh pengguna lain meskipun hak aksesnya hanya View. |
#
# ---
#
# ## Menu Format
#
# | Nama Menu             | Kegunaan                                                                                                  |
# |-----------------------|-----------------------------------------------------------------------------------------------------------|
# | Theme                 | Mengatur tema tampilan grafik.                                                                            |
# | Number                | Mengatur format penulisan angka (mata uang, tanggal, persen, dll).                                        |
# | Bold                  | Membuat angka atau kata menjadi tebal.                                                                    |
# | Italic                | Membuat angka atau kata menjadi miring.                                                                   |
# | Underline             | Membuat angka atau kata menjadi bergaris bawah.                                                           |
# | Strikethrough         | Membuat angka atau kata menjadi tercoret.                                                                 |
# | Font size             | Mengubah ukuran font.                                                                                     |
# | Align                 | Mengubah format penulisan (rata kanan, tengah, kiri).                                                     |
# | Merge cells           | Menggabungkan beberapa sel menjadi satu.                                                                  |
# | Text wrapping         | Membuat teks panjang menjadi beberapa baris dalam satu kolom.                                             |
# | Text rotation         | Mengubah orientasi posisi teks dalam sel.                                                                 |
# | Conditional formatting| Melakukan format penulisan secara kondisional.                                                            |
# | Alternating colors    | Memberikan warna pada sel sesuai pola tertentu.                                                           |
# | Clear formatting      | Menghilangkan semua format penulisan dalam sebuah sel.                                                    |
#
# ---
#
# ## Menu Data
#
# | Nama Menu                   | Kegunaan                                                                                           |
# |-----------------------------|----------------------------------------------------------------------------------------------------|
# | Sort sheet by column (A-Z)  | Menyortir data dalam kolom secara menaik.                                                          |
# | Sort sheet by column (Z-A)  | Menyortir data dalam kolom secara menurun.                                                         |
# | Sort range                  | Menyortir data dalam sel terpilih dengan parameter tertentu.                                       |
# | Create filter               | Mengurutkan dan mengelompokkan data dengan parameter tertentu.                                     |
# | Filter views                | Mempermudah pemantauan pengurutan data.                                                            |
# | Slicer                      | Mengatur data pada tabel pivot dan chart secara interaktif.                                        |
# | Data validation             | Memeriksa kebenaran data yang dimasukkan.                                                          |
# | Pivot table                 | Membuat pivot table untuk analisis data.                                                           |
# | Randomize range             | Mengacak urutan data.                                                                              |
# | Named ranges                | Memberi nama pada rentang data tertentu.                                                           |
# | Protected sheets and ranges | Mengunci sel tertentu dan membatasi akses pengguna lain.                                           |
# | Split text to column        | Memecah data dalam sel menjadi beberapa kolom.                                                     |
# | Remove duplicates           | Menghapus data duplikat dalam rentang tertentu.                                                    |
# | Trim whitespace             | Menghapus spasi berlebih di awal/akhir data.                                                       |
# | Group                       | Mengelompokkan baris/kolom ke dalam grup.                                                         |
# | Ungroup                     | Membatalkan pengelompokan data.                                                                    |
#
# ---
#
# ## Menu Tools
#
# | Nama Menu           | Kegunaan                                                                                                   |
# |---------------------|------------------------------------------------------------------------------------------------------------|
# | Create a form       | Membuat Google Form baru yang terhubung ke sheet.                                                          |
# | Script editor       | Membuat kustomisasi formula dengan script.                                                                 |
# | Macros              | Merekam dan menjalankan ulang serangkaian langkah secara otomatis.                                         |
# | Spelling            | Memeriksa penulisan teks.                                                                                  |
# | Enable autocomplete | Memberikan saran penulisan otomatis.                                                                       |
# | Notification rules  | Mengatur notifikasi perubahan pada spreadsheet.                                                            |
# | Accessibility settings | Mengaktifkan fitur aksesibilitas seperti screen reader.                                                 |
#
# ---
#
# ## Menu Add-ons
#
# | Nama Menu         | Kegunaan                                                                                                     |
# |-------------------|-------------------------------------------------------------------------------------------------------------|
# | Document add-ons  | Membuka daftar add-ons yang sudah aktif.                                                                    |
# | Get add-ons       | Membuka daftar add-ons yang bisa diaktifkan.                                                                |
# | Manage add-ons    | Mengatur add-ons yang sudah diaktifkan.                                                                     |
#
# ---
#
# ## Menu Help
#
# | Nama Menu                | Kegunaan                                                                                             |
# |--------------------------|------------------------------------------------------------------------------------------------------|
# | Search the menus (Alt+/) | Mencari opsi menu/submenu/tombol di Menu Bar.                                                        |
# | Sheets Help              | Membuka daftar bantuan Google Sheets.                                                                |
# | Training                 | Mengakses pelatihan online Google Sheets.                                                            |
# | Updates                  | Melihat fitur terbaru Google Sheets.                                                                 |
# | Help Sheets Improve      | Memberikan feedback ke Google.                                                                       |
# | Report abuse/copyright   | Melaporkan pelanggaran copyright atau peraturan.                                                     |
# | Privacy Policy           | Membuka kebijakan privasi Google.                                                                    |
# | Terms of Service         | Membuka ketentuan layanan Google.                                                                    |
# | Function list            | Membuka daftar fungsi (formula) Google Sheets.                                                       |
# | Keyboard shortcuts       | Membuka daftar pintasan keyboard Google Sheets.                                                      |

# %% [markdown]
# # Pengenalan Formula pada Spreadsheet
#
# Sebelum memulai pembahasan mengenai formula, ada baiknya kita menyegarkan ingatan tentang materi yang sudah dipelajari sebelumnya. Pada materi sebelumnya, kita telah belajar tentang navigasi hingga penyaringan data (filter).
#
# Namun, bagaimana jika kita ingin menganalisis data? Pasti dalam prosesnya tidak lepas dari perhitungan matematis dalam spreadsheet tersebut. Nah, di sinilah pentingnya formula yang dapat membantu kita dalam perhitungan mulai dari yang sederhana, seperti penjumlahan dan rata-rata, hingga yang kompleks.
#
# Formula merupakan sebuah langkah atau rumus untuk melakukan perhitungan matematis sehingga mendapatkan nilai tertentu. Istilah formula sendiri sudah sangat umum ditemui dalam aplikasi spreadsheet seperti Microsoft Excel, LibreOffice Calc, dan Google Sheets.
#
# ---
#
# ## Referensi Sel
#
# Sebuah formula pasti merujuk pada suatu alamat sel tertentu. Nah, rujukan alamat bisa disebut dengan **referensi sel**. Contoh sederhananya apabila kita ingin mengetahui jumlah nilai dari dua alamat sel, maka kita bisa menggunakan rumus penjumlahan sederhana seperti berikut.
#
# ![Contoh Referensi Sel](202004131719469ae123b19337019a47dbd5141e24fe8f.jpeg)
#
# Bagian A, B, C, dan seterusnya yang terbentang secara horizontal disebut **kolom**, sedangkan 1, 2, dan 3 yang membentang vertikal disebut **baris**. Gambar di atas juga menjelaskan bahwa terdapat data pada sel A1 bernilai 4 dan sel A2 bernilai 3. Kemudian, kita ingin mengetahui hasil penjumlahannya pada sel A3. Mulailah dengan tanda “=” diikuti dengan alamat sel `A1 + A2`. Pada akhirnya, formula tersebut menghasilkan nilai baru yaitu 7 pada sel A3.
#
# ![Hasil Penjumlahan Formula](2020041317242399b757e6afea5a42d2173eb1dba00b08.jpeg)
#
# Apabila nilai dari salah satu sel referensi (A1 atau A2) diubah, maka secara otomatis hasil penjumlahan di sel A3 juga berubah. Jika kita mengubah referensi sel, maka nilai yang tampil sebagai output di sel lain yang berisi rumus juga berubah.
#
# Contoh pada gambar di bawah, data pada sel A2 kita ubah dari angka 3 menjadi 4. Alhasil, pada kolom A3 akan otomatis berubah dari 7 menjadi 8.
#
# ![Perubahan Nilai Referensi Sel](20200413172822420f101c82fb913132d8b1ab46e2dd9d.jpeg)
#
# Berhati-hatilah dalam mengganti referensi sel yang berkaitan dengan rumus atau formula tertentu. Ini berlaku untuk semua penggunaan rumus yang ada di spreadsheet ya.
#
# ---
#
# Dengan menggabungkan operator matematika dengan referensi sel, Anda dapat menerapkannya di rumus lainnya dalam Google Sheets. Formula atau rumus juga dapat menyertakan kombinasi referensi sel dan angka, misalnya:
#
# | Penulisan Rumus | Keterangan                                      |
# |-----------------|-------------------------------------------------|
# | `A1+A2`         | Menjumlahkan nilai pada sel A1 dan A2.          |
# | `A1-A2`         | Nilai pada sel A1 dikurangi dengan nilai A2.    |
# | `A1/2`          | Nilai pada sel A1 dibagi dengan 2.              |
# | `A1*3`          | Nilai pada sel A1 dikali dengan 3.              |
# | `A1^2`          | Nilai pada sel A1 dipangkatkan 2.               |

# %% [markdown]
# Operator pada Spreadsheet
#
# Operator adalah simbol yang digunakan untuk melakukan perhitungan atau pemrosesan data dalam spreadsheet. Operator mengikuti urutan perhitungan matematika (perkalian/pembagian didahulukan sebelum penjumlahan/pengurangan) dan setiap formula diawali dengan tanda "=".
#
# ## Operator Aritmatika
#
# Digunakan untuk operasi matematika dasar:
#
# | Operator | Kegunaan      |
# |----------|--------------|
# | +        | Penjumlahan  |
# | -        | Pengurangan  |
# | /        | Pembagian    |
# | *        | Perkalian    |
# | ^        | Pangkat      |
# | %        | Persen       |
#
# ## Operator Perbandingan
#
# Digunakan untuk logika (hasil True/False):
#
# | Operator | Kegunaan                        |
# |----------|---------------------------------|
# | =        | Sama dengan                     |
# | >        | Lebih dari                      |
# | <        | Kurang dari                     |
# | >=       | Lebih dari atau sama dengan     |
# | <=       | Kurang dari atau sama dengan    |
# | <>       | Tidak sama dengan               |
#
# ## Operator Teks
#
# - `&` : Menggabungkan beberapa teks (concatenate).
#
# ## Operator Referensi
#
# Digunakan untuk menunjuk lokasi/range sel:
#
# | Operator | Kegunaan                                                                                   |
# |----------|--------------------------------------------------------------------------------------------|
# | :        | Range, menunjuk semua sel antara dua referensi (misal: A1:A10)                             |
# | ;        | Union, menggabungkan beberapa referensi/range (misal: A1:A3;B3:B6;A4)                      |
# | (spasi)  | Intersection, irisan dua referensi (misal: A1:A5 A1:C3)                                    |

# %% [markdown]
# # Elemen Formula dalam Spreadsheet
#
# Pernahkah Anda menulis sebuah fungsi sederhana dalam aplikasi spreadsheet? Pada materi sebelumnya, kita sudah berkenalan dengan formula, referensi sel, dan operator yang biasanya digunakan dalam spreadsheet. Nah, kini saatnya mulai menulis formula.
#
# Akan tetapi, sebelum mulai menulis formula, ada baiknya kita mempelajari dulu elemen-elemen dalam sebuah formula.
#
# Penulisan formula dalam spreadsheet diawali dengan tanda sama dengan “=”, sedangkan bagian-bagian dalam sebuah formula dapat terdiri dari satu atau lebih elemen berikut:
#
# - **Fungsi**
# - **Referensi sel (single/range)**
# - **Operator**
# - **Konstanta**
#
# Untuk memperjelas setiap elemennya, langsung lihat penjabarannya berdasarkan gambar di bawah ini.
#
# ![Elemen Formula Spreadsheet](20200413174510296804af186a642c648e1c3010f3a4cc.jpeg)
#
# ---
#
# ### Tanda Sama Dengan (“=”)
# Tanda sama dengan “=” merupakan elemen yang paling awal ditulis dalam sebuah formula apa pun sebelum lanjut ke elemen lainnya.
#
# ### Fungsi
# Fungsi merupakan sebuah penamaan yang telah ditentukan untuk melakukan kalkulasi data berdasarkan susunan argumen dalam aplikasi spreadsheet. Misal, kita ingin menghitung rata-rata menggunakan fungsi `AVERAGE`, total data menggunakan fungsi `SUM`, dan lainnya (akan dijelaskan lebih lanjut di materi berikutnya).
#
# ### Referensi Sel
# Telah disinggung di materi sebelumnya bahwa referensi sel merupakan acuan sebuah sel atau range dalam aplikasi spreadsheet, mulai dari sheet yang sama hingga berbeda berkas atau workbook. Pada contoh gambar di atas terdapat dua jenis referensi sel yaitu range yang ditunjukkan dengan `(A1:A5)` dan single sel yang ditunjukkan dengan alamat sel `B1`.
#
# ### Operator
# Operator juga termasuk salah satu elemen dalam penulisan formula spreadsheet. Seperti yang dijelaskan pada materi sebelumnya, ada banyak jenis di dalam operator, yaitu operator aritmatika, perbandingan, teks, dan referensi. Pada contoh gambar penulisan formula di atas, terdapat dua jenis operator, yaitu operator aritmatika dan referensi. Operator aritmatika terdapat pada tanda pembagian (“/”) dan perkalian (“*”), sedangkan operator referensi merujuk pada tanda titik dua (“:”) pada tulisan `(A1:A5)`.
#
# ### Konstanta
# Konstanta merupakan nilai masukan yang bukan berasal dari perhitungan karena nilainya selalu sama dan tidak pernah berubah. Bentuk dari konstanta bisa berupa teks atau angka, misalnya dalam contoh di atas konstanta ditunjukkan dengan angka 2.
#
# ---
#
# ## Tabel Formula Umum pada Spreadsheet
#
# | Nama Formula      | Penulisan Contoh         | Kegunaan                                                                 |
# |-------------------|-------------------------|--------------------------------------------------------------------------|
# | SUM               | `=SUM(A1:A5)`           | Menjumlahkan seluruh nilai pada range A1 sampai A5                       |
# | AVERAGE           | `=AVERAGE(B1:B10)`      | Menghitung rata-rata nilai pada range B1 sampai B10                      |
# | MIN               | `=MIN(C1:C10)`          | Mengambil nilai terkecil dari range C1 sampai C10                        |
# | MAX               | `=MAX(D1:D10)`          | Mengambil nilai terbesar dari range D1 sampai D10                        |
# | COUNT             | `=COUNT(E1:E10)`        | Menghitung jumlah sel yang berisi angka pada range E1 sampai E10         |
# | COUNTA            | `=COUNTA(F1:F10)`       | Menghitung jumlah sel yang tidak kosong pada range F1 sampai F10         |
# | IF                | `=IF(G1>10,"Ya","Tidak")` | Mengecek kondisi pada G1, jika lebih dari 10 hasil "Ya", selain itu "Tidak" |
# | CONCATENATE       | `=CONCATENATE(H1," ",H2)` | Menggabungkan isi sel H1 dan H2 dengan spasi di antaranya                |
# | LEFT              | `=LEFT(I1,3)`           | Mengambil 3 karakter pertama dari teks di sel I1                         |
# | RIGHT             | `=RIGHT(J1,2)`          | Mengambil 2 karakter terakhir dari teks di sel J1                        |
# | VLOOKUP           | `=VLOOKUP(K2,A1:B10,2,FALSE)` | Mencari nilai K2 pada kolom pertama range A1:B10 dan mengambil nilai di kolom ke-2 |
# | HLOOKUP           | `=HLOOKUP(L2,A1:F2,2,FALSE)` | Mencari nilai L2 pada baris pertama range A1:F2 dan mengambil nilai di baris ke-2  |
# | TODAY             | `=TODAY()`              | Menampilkan tanggal hari ini                                             |
# | NOW               | `=NOW()`                | Menampilkan tanggal dan waktu saat ini                                   |
#
# Tabel di atas hanya sebagian dari formula yang sering digunakan dalam spreadsheet. Masih banyak formula lain yang dapat digunakan sesuai kebutuhan analisis data Anda.

# %% [markdown]
# # Fungsi SUM, AVERAGE, COUNT, dan Variasinya pada Spreadsheet
#
# Fungsi-fungsi berikut sangat sering digunakan dalam pengolahan data di spreadsheet untuk melakukan perhitungan dasar maupun analisis sederhana.
#
# | Fungsi     | Penulisan Umum                                      | Keterangan                                                                                       | Contoh Penggunaan                        | Hasil Contoh                |
# |------------|-----------------------------------------------------|--------------------------------------------------------------------------------------------------|------------------------------------------|-----------------------------|
# | **SUM**    | `=SUM(range)`                                       | Menjumlahkan seluruh nilai pada range tertentu                                                   | `=SUM(B3:B12)`                           | Total stok barang            |
# | **SUMIF**  | `=SUMIF(range, "kriteria", sum_range)`              | Menjumlahkan nilai pada sum_range yang memenuhi kriteria pada range                              | `=SUMIF(C3:C12,"Buku tulis",D3:D12)`     | Total "Buku tulis" terjual   |
# | **SUMIFS** | `=SUMIFS(sum_range, kriteria_range1, "kriteria1", ...)` | Menjumlahkan nilai pada sum_range dengan beberapa kriteria pada beberapa range                   | `=SUMIFS(D3:D12,C3:C12,"Buku tulis",B3:B12,">=01/02/2020",B3:B12,"<=02/02/2020")` | Total "Buku tulis" terjual pada rentang tanggal tertentu |
# | **AVERAGE**| `=AVERAGE(range)`                                   | Menghitung rata-rata nilai pada range                                                            | `=AVERAGE(C3:C12)`                       | Rata-rata barang terjual     |
# | **COUNT**  | `=COUNT(range)`                                     | Menghitung jumlah sel berisi angka pada range                                                    | `=COUNT(C3:C12)`                         | Jumlah produk terjual (angka saja) |
# | **COUNTA** | `=COUNTA(range)`                                    | Menghitung jumlah sel tidak kosong pada range (angka, teks, dll)                                 | `=COUNTA(C3:C12)`                        | Jumlah produk terjual (termasuk teks) |
# | **COUNTIF**| `=COUNTIF(range, kriteria)`                         | Menghitung jumlah sel pada range yang memenuhi satu kriteria                                     | `=COUNTIF(C3:C12,"L")`                   | Jumlah laki-laki             |
# | **COUNTIFS**| `=COUNTIFS(range1, kriteria1, range2, kriteria2, ...)` | Menghitung jumlah sel pada beberapa range yang memenuhi beberapa kriteria                        | `=COUNTIFS(C3:C12,"L",D3:D12,"Sepak bola")` | Jumlah laki-laki yang hobi sepak bola |
#
# ---
#
# **Catatan:**
# - `range` adalah rentang sel yang ingin dihitung.
# - `sum_range` adalah rentang sel yang nilainya akan dijumlahkan.
# - `kriteria` bisa berupa angka, teks, atau ekspresi logika.
# - Untuk delimiter, gunakan koma (`,`) atau titik koma (`;`) sesuai pengaturan lokal spreadsheet Anda.
#
# Fungsi-fungsi ini sangat membantu dalam menganalisis data, baik untuk penjumlahan, rata-rata, maupun menghitung jumlah data dengan atau tanpa kriteria tertentu.

# %% [markdown]
# # Fungsi MIN, MAX, TRIM, REPLACE, UNIQUE, dan IF pada Spreadsheet
#
# ## MIN dan MAX
#
# Fungsi **MIN** digunakan untuk mencari nilai terendah dari suatu rentang data, sedangkan **MAX** untuk mencari nilai tertinggi.
# Penulisan:
# - `=MIN(range)`
# - `=MAX(range)`
#
# Contoh:
# Jika ingin mengetahui penjualan tertinggi dan terendah dari data pada rentang C3:C12:
# - `=MAX(C3:C12)` → hasil: nilai penjualan paling banyak (misal: 300)
# - `=MIN(C3:C12)` → hasil: nilai penjualan paling sedikit (misal: 50)
#
# ---
#
# ## TRIM
#
# Fungsi **TRIM** digunakan untuk menghilangkan spasi berlebih pada sebuah teks, sehingga data menjadi lebih rapi.
# Penulisan:
# - `=TRIM(teks)`
#
# Contoh:
# Jika sel A2 berisi teks dengan banyak spasi, gunakan `=TRIM(A2)` di sel B2 untuk merapikan teks tersebut.
#
# ---
#
# ## REPLACE
#
# Fungsi **REPLACE** digunakan untuk mengganti sebagian teks dalam sebuah string berdasarkan posisi dan panjang karakter yang ingin diganti.
# Penulisan:
# - `=REPLACE(text, position, length, new_text)`
#
# Contoh:
# - Mengganti huruf ke-4 pada "Buka" menjadi "u":
#     `=REPLACE(A2, 4, 1, "u")` → hasil: "Buku"
# - Mengganti kata "membaca" pada "Saya membaca buku" menjadi "menulis":
#     `=REPLACE(A3, 6, 7, "menulis")` → hasil: "Saya menulis buku"
# - Mengganti "Saya" pada "Saya123" menjadi "Aku":
#     `=REPLACE(A4, 1, 4, "Aku")` → hasil: "Aku123"
#
# ---
#
# ## UNIQUE
#
# Fungsi **UNIQUE** digunakan untuk mengambil data unik (tidak duplikat) dari sebuah range.
# Penulisan:
# - `=UNIQUE(range)`
#
# Contoh:
# Jika terdapat daftar nama barang pada kolom, gunakan `=UNIQUE(A2:A10)` untuk menampilkan hanya nama barang yang tidak duplikat.
#
# ---
#
# ## IF
#
# Fungsi **IF** digunakan untuk melakukan logika kondisi pada data.
# Penulisan:
# - `=IF(logical_test, value_if_true, value_if_false)`
#
# Contoh:
# - Menentukan status penjualan:
#     `=IF(C3>75, "Bagus", "Perlu ditingkatkan")`
# - IF bertingkat untuk penilaian huruf:
#     `=IF(D3>=90,"A",IF(D3>=80,"B",IF(D3>=70,"C",IF(D3>=60,"D","E"))))`
#
# ---
#
# Fungsi-fungsi di atas sangat membantu dalam pengolahan dan analisis data di spreadsheet, mulai dari mencari nilai ekstrim, merapikan data, mengganti teks, mencari data unik, hingga melakukan analisis logika sederhana maupun bertingkat.

# %% [markdown]
# # Pengenalan Pivot Table
#
# Pivot table adalah fitur spreadsheet yang digunakan untuk menganalisis, mengelompokkan, dan meringkas data secara fleksibel berdasarkan kategori tertentu tanpa perlu menulis rumus secara manual. Dengan pivot table, Anda dapat dengan mudah mengetahui jumlah, total, atau statistik lain dari data berdasarkan parameter yang diinginkan.
#
# ---
#
# ## Manfaat Pivot Table
#
# - Mengelompokkan data berdasarkan kategori (misal: jenis kos, pemilik, dsb).
# - Menampilkan ringkasan data (jumlah, total harga, rata-rata, dll).
# - Memudahkan analisis data tanpa rumus yang rumit.
# - Hasil dapat diubah dengan cepat hanya dengan beberapa klik.
#
# ---
#
# ## Contoh Penggunaan Pivot Table
#
# Misal, Anda memiliki data indekos berikut:
#
# | Pemilik | Jenis Kos | Harga/Bulan |
# |---------|-----------|-------------|
# | Alan    | Campur    | 800.000     |
# | Budi    | Putra     | 700.000     |
# | Budi    | Campur    | 750.000     |
# | Cici    | Putri     | 850.000     |
# | Dedi    | Putra     | 650.000     |
# | Dedi    | Putri     | 700.000     |
#
# ---
#
# ### Contoh Ringkasan Pivot Table
#
# | Pemilik | Campur | Putra | Putri | Total Kos | Total Harga/Bulan |
# |---------|--------|-------|-------|-----------|-------------------|
# | Alan    | 1      | 0     | 0     | 1         | 800.000           |
# | Budi    | 1      | 1     | 0     | 2         | 1.450.000         |
# | Cici    | 0      | 0     | 1     | 1         | 850.000           |
# | Dedi    | 0      | 1     | 1     | 2         | 1.350.000         |
#
# ---
#
# ## Langkah Membuat Pivot Table
#
# 1. **Siapkan data**: Pastikan data sudah rapi (kategori, nilai, dsb).
# 2. **Sorot seluruh data** yang akan dianalisis.
# 3. Pilih menu **Insert → Pivot table**.
# 4. Pilih lokasi hasil pivot (New Sheet/Existing Sheet).
# 5. Pada **Pivot table editor**:
#     - Tambahkan kategori ke bagian **Rows** (misal: Pemilik).
#     - Tambahkan kategori ke bagian **Columns** (misal: Jenis Kos).
#     - Tambahkan data ke bagian **Values** (misal: Jenis Kos untuk jumlah, Harga/Bulan untuk total).
# 6. Hasil pivot table akan langsung muncul dan dapat diubah sesuai kebutuhan.
#
# ---
#
# Pivot table sangat membantu dalam menganalisis data besar secara efisien dan fleksibel.

# %% [markdown]
# # Elemen Pivot Table
#
# Pivot table terdiri dari tiga elemen utama: **Baris (Rows)**, **Kolom (Columns)**, dan **Nilai (Values)**. Berikut rangkuman dan penjelasan singkatnya:
#
# | Elemen     | Penjelasan                                                                                                   | Contoh di Pivot Table                |
# |------------|-------------------------------------------------------------------------------------------------------------|--------------------------------------|
# | **Baris**  | Menampilkan data unik dari kolom tertentu secara horizontal (per baris).                                    | Daftar pemilik kos                   |
# | **Kolom**  | Menampilkan data unik dari kolom tertentu secara vertikal (per kolom).                                      | Jenis kos: Campur, Putra, Putri      |
# | **Nilai**  | Data yang dihitung berdasarkan fungsi tertentu (SUM, COUNT, COUNTA, dsb) sesuai kombinasi baris dan kolom.  | Jumlah kos, total harga, dsb         |
# | **Total**  | Menampilkan jumlah total (Grand Total) pada baris/kolom jika opsi Show totals diaktifkan.                   | Total keseluruhan per baris/kolom    |
# | **Pengurutan** | Mengurutkan data pada baris/kolom secara ascending/descending sesuai parameter yang dipilih.            | Urut nama pemilik A-Z/Z-A            |
#
# ---
#
# **Catatan:**
# - **Baris** dan **Kolom** diisi dengan data unik dari sumber data.
# - **Nilai** diisi dengan hasil perhitungan (misal: jumlah, rata-rata).
# - **Total** memudahkan melihat ringkasan keseluruhan.
# - **Pengurutan** membantu analisis data lebih terstruktur.
#
# Pivot table memudahkan analisis data tanpa rumus rumit, cukup dengan drag & drop elemen pada editor pivot table.

# %% [markdown]
# # Tips Pivot Table
#
# ---
#
# ## Rangkuman Tips Pivot Table
#
# | Fitur           | Langkah & Penjelasan                                                                                                 |
# |-----------------|----------------------------------------------------------------------------------------------------------------------|
# | **Grand Total** | - Pilih baris (misal: Jenis Kos) <br> - Tambahkan nilai (COUNTA untuk jumlah, AVERAGE untuk rata-rata harga)         |
# | **Filter Data** | - Tambahkan filter (misal: Jenis Kos) <br> - Pilih item yang ingin ditampilkan saja (misal: hanya Kos Putra)         |
# | **Detail Data** | - Klik dua kali pada sel value di pivot table <br> - Google Sheets membuat sheet baru berisi detail data tersebut    |
#
# ---
#
# ## Ilustrasi Fitur Pivot Table
#
# | Fitur         | Contoh Penggunaan                                      | Hasil yang Didapat                  |
# |---------------|--------------------------------------------------------|-------------------------------------|
# | Grand Total   | COUNTA Jenis Kos, AVERAGE Harga per-bulan              | Jumlah & rata-rata harga tiap jenis |
# | Filter        | Filter hanya Kos Putra                                 | Tabel hanya menampilkan Kos Putra   |
# | Detail Data   | Klik dua kali pada sel jumlah/rata-rata di pivot table | Sheet baru berisi data rinci        |
#
# ---
#
# Pivot table sangat fleksibel untuk menganalisis data secara cepat dan informatif.Pivot table sangat fleksibel untuk menganalisis data secara cepat dan informatif.

# %% [markdown]
# # Rangkuman Sub-modul Persiapan Data Pra-Visualisasi
#
# | Topik                        | Penjelasan                                                                                                                                                                                                                                                                                                                                                                   |
# |------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Kegunaan Spreadsheet**     | - Menyimpan informasi secara detail<br>- Membuat tabel data dengan mudah<br>- Membantu perhitungan statistik<br>- Memvisualisasikan data ke dalam grafik<br>- Lengkap dengan rumus-rumus perhitungan data                                                                                                                            |
# | **Aplikasi Spreadsheet**     | - Microsoft Excel<br>- LibreOffice Calc<br>- Google Sheets                                                                                                                                                                                                                                                                                                                  |
# | **Isi Sel Spreadsheet**      | - Angka: Untuk perhitungan matematis<br>- Teks: Untuk informasi seperti nama, keterangan<br>- Rumus: Untuk kalkulasi otomatis antar sel                                                                                                                                                                                             |
# | **Menu Bar Google Sheets**   | - Title bar: Judul berkas<br>- Menu bar: Menu File hingga Help                                                                                                                                                                                                                                                                                                              |
# | **Opsi Import File**         | - Create new spreadsheet<br>- Insert new sheet(s)<br>- Replace spreadsheet                                                                                                                                                                                                                                                           |
# | **Opsi Pengolahan Data**     | - Sortir data<br>- Penyaringan data (filter)<br>- Formula<br>- Pivot table                                                                                                                                                                                                                                                          |
# | **Operator Spreadsheet**     | - **Aritmatika**: +, -, *, /, ^, %<br>- **Perbandingan**: =, >, <, >=, <=, <><br>- **Teks**: & (menggabungkan teks)<br>- **Referensi**: :, ;, (spasi)                                                                                                                                                                              |
# | **Elemen Formula**           | - Sama dengan (“=”)<br>- Fungsi<br>- Referensi Sel<br>- Operator<br>- Konstanta                                                                                                                                                                                                                                                     |
# | **Fungsi Spreadsheet Umum**  | - **SUM**: Menjumlahkan nilai<br>- **SUMIF**: Menjumlahkan dengan satu kriteria<br>- **SUMIFS**: Menjumlahkan dengan banyak kriteria<br>- **AVERAGE**: Menghitung rata-rata<br>- **COUNT**: Menghitung jumlah sel berisi angka<br>- **COUNTA**: Menghitung jumlah sel tidak kosong<br>- **COUNTIF**: Menghitung jumlah sel sesuai satu kriteria<br>- **COUNTIFS**: Menghitung jumlah sel sesuai banyak kriteria<br>- **MIN**: Nilai terendah<br>- **MAX**: Nilai tertinggi<br>- **TRIM**: Menghilangkan spasi berlebih<br>- **REPLACE**: Mengganti sebagian teks<br>- **UNIQUE**: Mengambil data unik<br>- **IF**: Logika kondisi pada data |
# | **Pivot Table**              | Fitur untuk mengelompokkan dan meringkas data berdasarkan parameter tertentu tanpa rumus manual.                                                                                                                                                                                                                                     |
